# %%
import pandas as pd

# Load all datasets
ev_data = pd.read_csv('data/ev_data.csv')
charging_data = pd.read_csv('data/charging_data.csv')
trip_logs = pd.read_csv('data/trip_logs.csv')
chatbot_data = pd.read_csv('data/chatbot_data.csv')

# Display summaries
print("✅ EV Data:")
display(ev_data.head())
print("\nShape:", ev_data.shape)
print("\nColumns:", ev_data.columns)

print("\n✅ Charging Data:")
display(charging_data.head())
print("\nShape:", charging_data.shape)

print("\n✅ Trip Logs:")
display(trip_logs.head())
print("\nShape:", trip_logs.shape)

print("\n✅ Chatbot Data:")
display(chatbot_data.head())
print("\nShape:", chatbot_data.shape)
